# %% [markdown]
# ## Data load

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Training

# %%
# !python HDCN/hdcn_train.py

# %% [markdown]
# - 나머지는 각자 폴더에서 Hybrid_GDCN -> Hybrid_GDCN_train.ipynb -> XGB_train.ipynb
# -> Hybrid_GDCN_inference.ipynb -> XGB_inference.ipynb -> inference.ipynb

# %% [markdown]
# - xgb 는 샘플링 (2:1 6만데이터)
# - Hybrid GDCN 은 풀데이터
# - HDCN 은 풀데이터입니다.
# - 샘플링에 따라 성능이 달라질수있어, train.csv 첨부드립니다.
